# %% [markdown]
# <a href="https://colab.research.google.com/github/M-oses340/Chelsea-24-25-Epl-Data-Analysis/blob/main/Epl24_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Read the csv file fromthe URL
df_premier24 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
df_premier24
#Storing the data into a dataframe
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
#Rename the columns
df_premier24.rename(columns={'FTHG':'home_goals',
                             'FTR':'winner',
                             'HTHG':'home_goals_half_time',
                             'HTAG':'away_goals_half_time',
                             'HS':'home_shots',
                             'AS':'away_shots',
                             'FTAG':'away_goals'}, inplace=True)

# %%
#Show the updated dataframe
df_premier24
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  16/08/2024  20:00     Man United       Fulham           1
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool           0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves           2
# 3    E0  17/08/2024  15:00        Everton     Brighton           0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton           1
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton           0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea           0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal           1
# 378  E0  25/05/2025  16:00      Tottenham     Brighton           1
# 379  E0  25/05/2025  16:00         Wolves    Brentford           1
#
#      away_goals winner  home_goals_half_time  away_goals_half_time  ...  \
# 0             0      H                     0                     0  ...
# ...

# %%
#Find the number of times Chelsea played away.
df_premier24['AwayTeam'] == "Chelsea"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 375    False
# 376     True
# 377    False
# 378    False
# 379    False
# Name: AwayTeam, Length: 380, dtype: bool

# %%
#Getting summary statistics
df_chelsea.describe()
# Out:
#        home_goals  away_goals  home_goals_half_time  away_goals_half_time  \
# count   19.000000   19.000000             19.000000             19.000000
# mean     1.315789    1.526316              0.684211              0.631579
# std      1.056863    1.775400              0.749269              0.895081
# min      0.000000    0.000000              0.000000              0.000000
# 25%      0.500000    0.000000              0.000000              0.000000
# 50%      1.000000    1.000000              1.000000              0.000000
# 75%      2.000000    2.000000              1.000000              1.000000
# max      3.000000    6.000000              2.000000              3.000000
#
#        home_shots  away_shots        HST        AST         HF         AF  \
# count   19.000000   19.000000  19.000000  19.000000  19.000000  19.000000
# mean    10.947368   13.526316   4.473684   4.789474  12.684211  11.631579
# std      3.908306    4.948270   1.866917   3.154872   3.986820   2.671049
# ...

# %%
df_chelsea.head()
# Out:
#    Div        Date   Time     HomeTeam AwayTeam  home_goals  away_goals  \
# 18  E0  25/08/2024  14:00       Wolves  Chelsea           2           6
# 37  E0  14/09/2024  20:00  Bournemouth  Chelsea           0           1
# 40  E0  21/09/2024  12:30     West Ham  Chelsea           0           3
# 78  E0  20/10/2024  16:30    Liverpool  Chelsea           2           1
# 98  E0  03/11/2024  16:30   Man United  Chelsea           1           1
#
#    winner  home_goals_half_time  away_goals_half_time  ... B365CAHH B365CAHA  \
# 18      A                     2                     2  ...     1.99     1.94
# 37      A                     0                     0  ...     1.95     1.98
# 40      A                     0                     2  ...     1.90     2.03
# 78      H                     1                     0  ...     1.90     2.03
# 98      D                     0                     0  ...     1.99     1.94
#
# ...

# %%
# Analyze the 'winner' column for Chelsea's away games
winner_counts = df_chelsea['winner'].value_counts()
print("Analysis of 'winner' column for Chelsea away games:")
display(winner_counts)
# Out:
# Analysis of 'winner' column for Chelsea away games:
# winner
# A    8
# H    7
# D    4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bar chart of the winner counts
plt.figure(figsize=(6, 4))
sns.barplot(x=winner_counts.index, y=winner_counts.values)
plt.title('Chelsea Away Game Results')
plt.xlabel('Result')
plt.ylabel('Number of Games')
plt.show()

# %%
import numpy as np
np.where(df_chelsea['winner'] == 'A', 'Won', df_chelsea['winner'])
# Out:
# array(['Won', 'Won', 'Won', 'H', 'D', 'Won', 'Won', 'Won', 'D', 'H', 'D',
#        'H', 'H', 'H', 'H', 'D', 'Won', 'H', 'Won'], dtype=object)

# %%
(df_premier24['AwayTeam'] == 'Chelsea') & (df_premier24['winner'] == 'A')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 375    False
# 376     True
# 377    False
# 378    False
# 379    False
# Length: 380, dtype: bool

# %%
df_premier24[(df_premier24['AwayTeam'] == 'Chelsea') & (df_premier24['winner'] == 'A')]
# Out:
#     Div        Date   Time       HomeTeam AwayTeam  home_goals  away_goals  \
# 18   E0  25/08/2024  14:00         Wolves  Chelsea           2           6
# 37   E0  14/09/2024  20:00    Bournemouth  Chelsea           0           1
# 40   E0  21/09/2024  12:30       West Ham  Chelsea           0           3
# 110  E0  23/11/2024  12:30      Leicester  Chelsea           1           2
# 135  E0  04/12/2024  19:30    Southampton  Chelsea           1           5
# 147  E0  08/12/2024  16:30      Tottenham  Chelsea           3           4
# 325  E0  20/04/2025  14:00         Fulham  Chelsea           1           2
# 376  E0  25/05/2025  16:00  Nott'm Forest  Chelsea           0           1
#
#     winner  home_goals_half_time  away_goals_half_time  ... B365CAHH B365CAHA  \
# 18       A                     2                     2  ...     1.99     1.94
# 37       A                     0                     0  ...     1.95     1.98
# ...
